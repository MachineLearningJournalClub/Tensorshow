# %% [markdown]
# # It's time to begin
#
# Earlier we mentioned that
# *machine learning* is all about a computer learning the *patterns*
# that distinguish things. Like for **activity recognition**, it was the pattern of walking, running and biking
# that can be learned from various sensors on a device. To show how that works, let's take a look
# at a set of numbers and see if you can determine
# the pattern between them.
#
# <img src="https://raw.githubusercontent.com/simoneazeglio/MLJCTensorshow/master/Lecture1/Immagini/S1N2.png">

# %% [markdown]
# Okay, here are the numbers. There's a formula
# that maps $x$ to $y$. Can you spot it? Take a moment.
#
# Well, the answer is
# $y = 2x - 1$. If you've got it right, congratulations! You have succeeded in a Learning task implicitly.

# %% [markdown]
# So, for example, if you were writing code for a function like this, you already know the *rules*

# %%
# Defining a function requires def in Python 
def test_function(x):
    y = 2*x -1 
    return y

# %%
# Example 
test_function(10)
# Out:
# 19

# %% [markdown]
# ### Imports
# Let's start with our imports. Here we are importing **TensorFlow** and calling it **tf** for ease of use.
# We then import a library called **Numpy**, which helps us to represent our data as arrays easily and quickly.
# The framework for defining a neural network as a set of *Sequential* layers is called **Keras**, which is already "inside" Tensorflow.

# %%
import tensorflow as tf
import numpy as np

# %%
tf.__version__
# Out:
# '1.13.1'

# %% [markdown]
# ### Define and compile the Neural Network
# [ **TIP** : https://keras.io/getting-started/sequential-model-guide/ ]
#
# Next we will create the simplest possible neural network. It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value. (Do you recall *Linear Regression*?)

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/MLJCUnito/Tensorshow/master/Immagini/BillNeural.png">

# %% [markdown]
# Now we compile our Neural Network. If you've seen lots of math for machine learning, here's where it's usually used, but in this case it's nicely encapsulated in functions for you. But what happens here? Let's explain...
#
# We know that in our function, the relationship between the numbers is *y=2x-1*.
#
# When the computer is trying to *'learn'* that, it makes a guess...something like, let's say,  *y=10x+10*. The **loss function** measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the **optimizer function** to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with somehting like *y=5x+5*, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower)
#
# It will repeat this for the number of **epochs** which you will see shortly. But first, here's how we tell it to use **mean squared error** for the loss and **stochastic gradient descent**' for the optimizer. You don't need to understand the math for these yet, but you can see that they work! :)
#
# Over time you will learn the different and appropriate loss and optimizer functions for different scenarios.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ### Providing the Data
#
# Next up we'll feed in some data. Actually the two lists that we've seen before in the image.
# A python library called 'Numpy' provides lots of array type data structures that are a defacto standard way of doing it. We declare that we want to use these by specifying the values as an np.array[ ]

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0])
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0])

# %% [markdown]
# ## Training the Neural Network
#
# The process of training the neural network, where it 'learns' the relationship between the Xs and Ys is in the **model.fit** call. This is where it will go through the loop we spoke about above, making a guess, measuring how good or bad it is (aka the loss), using the opimizer to make another guess etc. It will do it for the number of epochs you specify. When you run this code, you'll see the loss on the right hand side.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 6/6 [==============================] - 0s 21ms/sample - loss: 44.0604
# Epoch 2/500
# 6/6 [==============================] - 0s 221us/sample - loss: 35.0357
# Epoch 3/500
# 6/6 [==============================] - 0s 578us/sample - loss: 27.9279
# Epoch 4/500
# 6/6 [==============================] - 0s 455us/sample - loss: 22.3283
# Epoch 5/500
# 6/6 [==============================] - 0s 570us/sample - loss: 17.9155
# Epoch 6/500
# 6/6 [==============================] - 0s 723us/sample - loss: 14.4366
# Epoch 7/500
# 6/6 [==============================] - 0s 399us/sample - loss: 11.6926
# Epoch 8/500
# 6/6 [==============================] - 0s 480us/sample - loss: 9.5268
# ...

# %% [markdown]
# Ok, now you have a model that has been trained to learn the relationshop between X and Y. You can use the model.predict method to have it figure out the Y for a previously unknown X. So, for example, if X = 10, what do you think Y will be? Take a guess before you run this code:

# %%
print(model.predict([10.0]))
# Out:
# [[18.977175]]

# %% [markdown]
# You might have thought 19, right? But it ended up being a little under. Why do you think that is?
# Remember that neural networks deal with probabilities, so given the data that we fed the NN with, it calculated that there is a very high probability that the relationship between X and Y is Y=2X-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
# As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.

# %% [markdown]
# __After all Machine Learning is not an exact science, unless you are overfitting__
